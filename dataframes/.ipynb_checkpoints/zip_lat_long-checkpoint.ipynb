# %%
zip_lat_long.to_pickle('./dataframes/zip_lat_long.pkl')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-027742f3add2> in <module>()
# ----> 1 zip_lat_long.to_pickle('./dataframes/zip_lat_long.pkl')
#
# AttributeError: 'dict' object has no attribute 'to_pickle'

# %%
zip_lat_long
# Out:
# {'90000': {'latitude': 47.6437604, 'longitude': 6.8437053},
#  '90001': {'latitude': 33.9697897, 'longitude': -118.2468148},
#  '90002': {'latitude': 33.9511133, 'longitude': -118.2497386},
#  '90003': {'latitude': 33.9657994, 'longitude': -118.2731269},
#  '90004': {'latitude': 34.0748887, 'longitude': -118.3082034},
#  '90006': {'latitude': 34.0470832, 'longitude': -118.2965121},
#  '90007': {'latitude': 34.0295114, 'longitude': -118.2848199},
#  '90008': {'latitude': 34.0083231, 'longitude': -118.3491169},
#  '90011': {'latitude': 34.007889, 'longitude': -118.2585096},
#  '90012': {'latitude': 34.0653347, 'longitude': -118.243891},
#  '90014': {'latitude': 34.0434783, 'longitude': -118.2519314},
#  '90015': {'latitude': 34.0390107, 'longitude': -118.2672801},
#  '90016': {'latitude': 34.0255188, 'longitude': -118.3520389},
#  '90017': {'latitude': 34.0543797, 'longitude': -118.2672801},
#  '90018': {'latitude': 34.0309972, 'longitude': -118.319894},
# ...
