# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
incident_df = pd.read_csv('./URSUS/URSUS_Incident_2016.csv')
incident_df = pd.DataFrame(incident_df)

# %%
incident_df = incident_df.drop('ORI', axis=1)

# %%
incident_df.to_pickle('incident_df.pkl')

# %%
incident_df[incident_df['County'] == 'Los Angeles County']
# Out:
#                 Incident_ID Incident_Date_Str  Incident_Time_Str  \
# 128  URSUS-19-0000-2016-AJG         2/21/2016                340
# 129  URSUS-19-0000-2016-AQC         1/14/2016               1945
# 130  URSUS-19-0000-2016-BFQ         10/5/2016               1224
# 131  URSUS-19-0000-2016-CFX          8/7/2016               1219
# 132  URSUS-19-0000-2016-CMT         5/31/2016                 19
# 133  URSUS-19-0000-2016-DAY         4/27/2016                630
# 134  URSUS-19-0000-2016-DBJ        12/15/2016               2300
# 135  URSUS-19-0000-2016-DXN         2/14/2016                350
# 136  URSUS-19-0000-2016-DZT        12/27/2016               1415
# 137  URSUS-19-0000-2016-EFK         3/30/2016               1221
# 138  URSUS-19-0000-2016-EMW          9/8/2016               1811
# 139  URSUS-19-0000-2016-EUT         2/10/2016               1153
# 140  URSUS-19-0000-2016-EXQ         10/7/2016                909
# ...

# %%
time_sequence = [x*100 for x in range(24)]

# %%
sns.distplot(incident_df['Incident_Time_Str'], bins=time_sequence, hist=True)

# %%
plt.hist(incident_df['Incident_Time_Str'], bins=time_sequence)
plt.show()

# %%
la_weather = pd.read_csv('./la_noaa_weather.csv', sep=',')

# %%
la_weather = la_weather[la_weather['NAME'] == 'LOS ANGELES INTERNATIONAL AIRPORT, CA US']

# %%
la_weather.sort_values(by='SNOW', ascending=False)
# Out:
#          STATION                                      NAME        DATE  PRCP  \
# 0    USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-01-01  0.00
# 251  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-08  0.00
# 249  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-06  0.00
# 248  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-05  0.00
# 247  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-04  0.00
# 246  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-03  0.00
# 245  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-02  0.00
# 244  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-09-01  0.00
# 243  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-08-31  0.00
# 242  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-08-30  0.00
# 241  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US  2016-08-29  0.00
# ...
